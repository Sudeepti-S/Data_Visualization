# %%
import pandas as pd

# %%
df_test = pd.read_csv('clean_output.csv')
# Out:
# /apps/software/standard/compiler/gcc/7.1.0/jupyter_conda/2019.10-py3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,1,6,7,8,9,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_test.head(5)
# Out:
#   Unnamed: 0             user_id            created_at     screen_name  \
# 0          2          2255210942  2020-03-04T11:09:57Z  David_Mulroney
# 1          3           366491737  2020-03-04T11:10:09Z  MarykeSchoonen
# 2          4            61557732  2020-03-04T11:10:21Z      Arjit_Garg
# 3          5  828841083257778176  2020-03-04T11:10:48Z        latestly
# 4          6  819488066251423744  2020-03-04T11:11:39Z    daily_thetha
#
#                                                 text               source  \
# 0  China’s wildlife trade via @SCMPgraphics  http...     Twitter for iPad
# 1  Proof that the media such as @CNN is unnecessa...   Twitter for iPhone
# 2  Indians are a shitty breed of humans. With the...  Twitter for Android
# 3  #CoronavirusOutbreak in India: Techies at #Hyd...      Twitter Web App
# 4  Today’s insightful episode answered the freque...   Twitter for iPhone
#
#   is_quote is_retweet favourites_count retweet_count  followers_count  \
# ...

# %%
df_test.describe()
# Out:
#        followers_count  friends_count       positive       negative
# count     2.484530e+05   2.484530e+05  248451.000000  248451.000000
# mean      7.148044e+04   2.342775e+03       0.827414       0.779575
# std       6.902480e+05   1.030159e+04       1.003357       0.978339
# min       0.000000e+00   0.000000e+00       0.000000       0.000000
# 25%       1.590000e+02   1.960000e+02       0.000000       0.000000
# 50%       7.860000e+02   6.340000e+02       0.550000       0.460000
# 75%       3.498000e+03   1.850000e+03       1.390000       1.330000
# max       1.508450e+07   1.506570e+06       8.110000       8.750000

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248457 entries, 0 to 248456
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        248457 non-null  object
#  1   user_id           248455 non-null  object
#  2   created_at        248455 non-null  object
#  3   screen_name       248455 non-null  object
#  4   text              248455 non-null  object
#  5   source            248453 non-null  object
#  6   is_quote          248453 non-null  object
#  7   is_retweet        248453 non-null  object
#  8   favourites_count  248453 non-null  object
#  9   retweet_count     248453 non-null  object
#  10  followers_count   248453 non-null  float64
#  11  friends_count     248453 non-null  float64
#  12  verified          248451 non-null  object
#  13  lang              248451 non-null  object
#  14  positive          248451 non-null  float64
# ...

# %%
#df_test['favourites_count'] = df_test['favourites_count'].astype(float)
df_test['favourites_count'] = pd.to_numeric(df_test['favourites_count'],errors='coerce')
df_test['retweet_count'] = pd.to_numeric(df_test['retweet_count'],errors='coerce')

# %%
print (df_test.dtypes)
# Out:
# Unnamed: 0           object
# user_id              object
# created_at           object
# screen_name          object
# text                 object
# source               object
# is_quote             object
# is_retweet           object
# favourites_count    float64
# retweet_count       float64
# followers_count     float64
# friends_count       float64
# verified             object
# lang                 object
# positive            float64
# negative            float64
# dtype: object

# %%
df_test.describe()
# Out:
#        favourites_count  retweet_count  followers_count  friends_count  \
# count      2.484510e+05  248451.000000     2.484530e+05   2.484530e+05
# mean       1.762366e+04       5.407738     7.148044e+04   2.342775e+03
# std        4.718260e+04     123.732530     6.902480e+05   1.030159e+04
# min        0.000000e+00       0.000000     0.000000e+00   0.000000e+00
# 25%        4.820000e+02       0.000000     1.590000e+02   1.960000e+02
# 50%        3.144000e+03       0.000000     7.860000e+02   6.340000e+02
# 75%        1.358800e+04       1.000000     3.498000e+03   1.850000e+03
# max        1.518821e+06   28159.000000     1.508450e+07   1.506570e+06
#
#             positive       negative
# count  248451.000000  248451.000000
# mean        0.827414       0.779575
# std         1.003357       0.978339
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.550000       0.460000
# 75%         1.390000       1.330000
# ...

# %%
df_final = df_test.loc[(df_test['positive'] != 0) & (df_test['negative'] != 0)]

# %%
# 56565

# %%
df_final.info()
df_final.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77621 entries, 3 to 248456
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        77621 non-null  object
#  1   user_id           77619 non-null  object
#  2   created_at        77619 non-null  object
#  3   screen_name       77619 non-null  object
#  4   text              77619 non-null  object
#  5   source            77617 non-null  object
#  6   is_quote          77617 non-null  object
#  7   is_retweet        77617 non-null  object
#  8   favourites_count  77615 non-null  float64
#  9   retweet_count     77615 non-null  float64
#  10  followers_count   77617 non-null  float64
#  11  friends_count     77617 non-null  float64
#  12  verified          77615 non-null  object
#  13  lang              77615 non-null  object
#  14  positive          77615 non-null  float64
#  15  negative          77615 non-null  float64
# ...

# %%
df_final = df_final.loc[(df_test['retweet_count'] != 0)]

# %%
df_final.info()
df_final.sample()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26042 entries, 22 to 248449
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        26042 non-null  object
#  1   user_id           26040 non-null  object
#  2   created_at        26040 non-null  object
#  3   screen_name       26040 non-null  object
#  4   text              26040 non-null  object
#  5   source            26038 non-null  object
#  6   is_quote          26038 non-null  object
#  7   is_retweet        26038 non-null  object
#  8   favourites_count  26036 non-null  float64
#  9   retweet_count     26036 non-null  float64
#  10  followers_count   26038 non-null  float64
#  11  friends_count     26038 non-null  float64
#  12  verified          26036 non-null  object
#  13  lang              26036 non-null  object
#  14  positive          26036 non-null  float64
#  15  negative          26036 non-null  float64
# ...

# %%
df_final.to_csv('FINAL_CLEAN_DATA.csv')
